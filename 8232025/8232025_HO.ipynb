# %%
import sample as sp

# %%
./sample.py -f 20150104 -t ADBE -o "/Users/Jojie/Documents/Practitioner's Seminar/8232025/"
# Out:
#   Cell In[5], line 1
#     -f 20150104 -t ADBE -o "/Users/Jojie/Documents/Practitioner's Seminar/8232025/"
#        ^
# SyntaxError: invalid syntax
